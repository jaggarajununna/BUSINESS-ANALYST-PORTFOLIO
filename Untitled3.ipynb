# %% [markdown]
# Import required libraries

# %%
import pandas as pd
import numpy as np
import ydata_profiling as yp

# %% [markdown]
# Import dataset

# %%
dt=pd.read_csv("B:\\datasets\\data cleaning.csv")

# %% [markdown]
# Descriptive stats of data

# %%
yp.ProfileReport(dt)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-29 12:23:45.572243&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
dt
# Out:
#      sno               name   marks
# 0    1.0     jaggaraju@0007      12
# 1    2.0  raghav!#$%^&aramu      15
# 2    3.0     ravirahul $%^&      18
# 3    4.0          rajesh%^&      21
# 4    5.0         ramesh@#$%       &
# 5    NaN                 11      27
# 6    7.0              raghu      30
# 7    8.0               siva       ^
# 8    9.0                sri      36
# 9   10.0                sam      39
# 10  11.0              sahul       $
# 11   NaN                  $  45^&*)
# 12  13.0                  %      48
# 13  14.0                  ^     NaN
# 14   NaN                NaN  54%^^^
# 15  16.0              easha       &
# 16  17.0               ravi      60
# 17  18.0                  8      63
# 18  19.0                ram      66
# 19  20.0             !@#$%^      69
# 20   NaN          123456789     NaN
# 21   NaN                 {}     NaN
# 22   NaN                [][     NaN
# 23   NaN                 \\     NaN
# 24   NaN                 \\     NaN
# ...

# %% [markdown]
# cleaning the dataset

# %%
dt['marks']=dt['marks'].str.strip('[!#$%@}{][\|^&''""*^)(]')

# %%
dt['name']=dt['name'].str.strip('[!#$%@}{][\|^&''""*^)(1234567890]')

# %%
dt=dt.iloc[:20]

# %%
dt=dt.fillna(' ')

# %%
dt
# Out:
#      sno               name marks
# 0    1.0          jaggaraju    12
# 1    2.0  raghav!#$%^&aramu    15
# 2    3.0         ravirahul     18
# 3    4.0             rajesh    21
# 4    5.0             ramesh
# 5                              27
# 6    7.0              raghu    30
# 7    8.0               siva
# 8    9.0                sri    36
# 9   10.0                sam    39
# 10  11.0              sahul
# 11                             45
# 12  13.0                       48
# 13  14.0
# 14                             54
# 15  16.0              easha
# 16  17.0               ravi    60
# 17  18.0                       63
# 18  19.0                ram    66
# 19  20.0                       69
